# %%
1. What is a parameter?
A parameter is a configuration variable internal to the model which is estimated from data (e.g., weights in linear regression).

2. What is correlation?
Correlation is a statistical measure that expresses the extent to which two variables are linearly related.

3. What does negative correlation mean?
Negative correlation means that as one variable increases, the other decreases. Example: More exercise, less weight.

4. Define Machine Learning. What are the main components in Machine Learning?
Definition: ML is the field that allows computers to learn from data without being explicitly programmed.
Main components: Data, Model, Loss Function, Optimizer, Evaluation Metric.

5. How does loss value help in determining whether the model is good or not?
Lower loss indicates better model performance since it means predictions are closer to actual values.

6. What are continuous and categorical variables?
Continuous: Numerical values (e.g., age, salary).

Categorical: Discrete labels (e.g., gender, city).

7. How do we handle categorical variables in Machine Learning? What are the common techniques?
Techniques include:

Label Encoding

One-Hot Encoding

Ordinal Encoding

Target Encoding

8. What do you mean by training and testing a dataset?
Training: Used to train the model.

Testing: Used to evaluate how well the model generalizes to unseen data.

9. What is sklearn.preprocessing?
A module in Scikit-learn for preprocessing tasks like scaling, encoding, and transforming data.

10. What is a Test set?
A portion of the dataset reserved to evaluate the model's final performance.

11. How do we split data for model fitting (training and testing) in Python?
Using train_test_split() from sklearn.model_selection.

python
Copy
Edit
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
12. How do you approach a Machine Learning problem?
Steps:

Understand the problem

Collect data

Preprocess the data

Split data

Train model

Evaluate and tune

Deploy

13. Why do we have to perform EDA before fitting a model to the data?
EDA helps discover patterns, detect outliers, and understand data distributions which improve model accuracy and trust.

14. What is correlation?
Repeated. (See Q2)

15. What does negative correlation mean?
Repeated. (See Q3)

16. How can you find correlation between variables in Python?
Using .corr() in pandas:

python
Copy
Edit
df.corr()
17. What is causation? Explain difference between correlation and causation with an example.
Causation: One variable directly affects the other.

Example: Ice cream sales and temperature have correlation; but temp causes sales, not vice versa.

18. What is an Optimizer? What are different types of optimizers? Explain each with an example.
Optimizers adjust model weights to minimize loss.
Examples:

SGD: Stochastic Gradient Descent

Adam: Adaptive learning

RMSProp: Root Mean Square Propagation

19. What is sklearn.linear_model?
A module in Scikit-learn for linear models like Linear Regression, Ridge, Lasso.

20. What does model.fit() do? What arguments must be given?
Trains the model on training data.
Arguments: X_train, y_train

python
Copy
Edit
model.fit(X_train, y_train)
21. What does model.predict() do? What arguments must be given?
Makes predictions using the trained model.
Argument: New input data X_test.

python
Copy
Edit
model.predict(X_test)
22. What are continuous and categorical variables?
Repeated. (See Q6)

23. What is feature scaling? How does it help in Machine Learning?
Transforms features to be on a similar scale. Helps models converge faster and improves performance.
Methods:

StandardScaler

MinMaxScaler

24. How do we perform scaling in Python?
Using StandardScaler or MinMaxScaler:

python
Copy
Edit
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
25. What is sklearn.preprocessing?
Repeated. (See Q9)

26. How do we split data for model fitting (training and testing) in Python?
Repeated. (See Q11)

27. Explain data encoding.
Data encoding converts categorical variables into numerical form.
Methods:

Label Encoding

One-Hot Encoding
